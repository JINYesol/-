# %% [markdown]
# <a href="https://colab.research.google.com/github/JINYesol/-/blob/main/04_02_%EC%96%B8%EC%96%B4%EB%B6%84%EC%84%9D_%EC%A4%91%EA%B5%AD%EC%96%B4_%EC%8B%AC%ED%99%94_year_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 환경 준비

# %%
# jieba 설치하기
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.6/dist-packages (0.42.1)

# %%
# jieba 실행하기
import jieba
## pandas을 실행하기, 단 실행 별명을 pd로
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
# 구글 드라이브 연결을 위한 기본 세팅 
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
## 문서 ID로 실제 파일 불러오기
# 실습을 위한 중국 역대 신년사 1992-2020
## https://drive.google.com/file/d/1GYehVwaJioXOYZMqH0v0E3pkAkic0Ydr/view?usp=sharing

rawdata_downloaded = drive.CreateFile({'id': '1GYehVwaJioXOYZMqH0v0E3pkAkic0Ydr'})
rawdata_downloaded.GetContentFile('rawdata.tsv')

# %%
# "rawdata.tsv" 파일의 내용을 "원본데이터" 변수로 불러오기
원본데이터 = pd.read_csv('rawdata.tsv', sep="\t")

# %%
# "원본데이터" 변수 내용 확인하기
원본데이터
# Out:
#     id  year person                                               text
# 0    1  1992    杨尚昆  女士们、先生们、朋友们：\n在岁序更新之际，我通过中国国际广播电台，向海外各位朋友致以亲切的...
# 1    2  1993    杨尚昆  各位听众朋友：\n1993年来到了，我很高兴再次通过中国国际广播电台向各国朋友、台湾同胞、港...
# 2    3  1994    江泽民  女士们，先生们，朋友们：\n在1994年到来之际，我很高兴在北京通过中国国际广播电台，向各国...
# 3    4  1995    江泽民  女士们、先生们、朋友们：\n在1995年到来之际，我很高兴再次通过中国国际广播电台，向各国人...
# 4    5  1996    江泽民  女士们、先生们、朋友们：\n在这辞旧迎新的美好时刻，我很高兴通过中国国际广播电台和中央电视台...
# 5    6  1997    江泽民  女士们、先生们、朋友们：\n在1997年到来的钟声即将敲响的时刻，我很高兴地通过中国国际广播...
# 6    7  1998    江泽民  同胞们、朋友们、女士们、先生们：\n在1998年来临之际，我十分高兴地通过中央人民广播电台、...
# 7    8  1999    江泽民  女士们，先生们，同志们，朋友们：\n1999年的新年钟声就要敲响了，人类又向新世纪迈进了一步...
# 8    9  2000    江泽民  女士们，先生们，同志们，朋友们：\n二○○○年到来的钟声，就要鸣响在我们这个星球的寥廓上空。...
# 9   10  2001    江泽民  女士们，先生们，同志们，朋友们：\n2001年新年钟声即将敲响。人类社会前进的航船就要驶入2...
# 10  11  2002    江泽民  女士们，先生们，同志们，朋友们：\n在2002年新年钟声即将敲响之际，我很高兴通过中国国际广...
# 11  12  2003    江泽民  女士们，先生们，同志们，朋友们：\n二00三年的新年钟声即将敲响。在新的一年到来的时刻，我很...
# 12  13  2004    胡锦涛  女士们，先生们，同志们，朋友们：\n2004年的新年钟声即将敲响。在这辞旧迎新的美好时刻，我...
# 13  14  2005    胡锦涛  女士们，先生们，同志们，朋友们：\n2005年新年钟声即将鸣响。在这辞旧迎新的时刻，我很高兴...
# 14  15  2006    胡锦涛  女士们，先生们，同志们，朋友们：\n2006年的新年钟声即将敲响。在这辞旧迎新的美好时刻，我...
# 15  16  2007    胡锦涛  女士们，先生们，同志们，朋友们：\n新年的钟声即将敲响。值此世界各国人民共迎2007年到来的...
# 16  17  2008    胡锦涛  女士们，先生们，同志们，朋友们：\n新年的钟声即将敲响，2008年就要到来了。在这个充满希望...
# 17  18  2009    胡锦涛  女士们，先生们，同志们，朋友们：\n新年的钟声就要敲响，我们即将开始2009年的崭新岁月。值...
# 18  19  2010    胡锦涛  女士们，先生们，同志们，朋友们：\n新年的钟声就要敲响，2010年的帷幕即将拉开。在这辞旧迎...
# 19  20  2011    胡锦涛  新年钟声即将敲响，人类就要进入2011年。在这辞旧迎新的美好时刻，我很高兴通过中国国际广播电...
# 20  21  2012    胡锦涛  2012年的新年钟声即将敲响。在这辞旧迎新的美好时刻，我很高兴通过中国国际广播电台、中央人民...
# 21  22  2013    胡锦涛  新年钟声就要敲响，2013年即将来临。我很高兴通过中国国际广播电台、中央人民广播电台和中央电...
# 22  23  2014    习近平  我们即将迎来充满希望的2014年。\n一元复始，万象更新。在这里，我向全国各族人民，向香港特...
# 23  24  2015    习近平  时间过得真快，2014年就要过去了，2015年正在向我们走来。在这辞旧迎新的时刻，我向全国各...
# 24  25  2016    习近平  同志们、朋友们、女士们、先生们：\n再过几个小时，新年的钟声就要敲响了。我们即将告别2015...
# 25  26  2017    习近平  2016年即将过去，新年的钟声即将敲响。\n在这辞旧迎新的美好时刻，我向全国各族人民，向香港...
# 26  27  2018    习近平  大家好！时光飞逝，转眼我们将迎来2018年。在这里，我向全国各族人民，向香港特别行政区同胞、...
# 27  28  2019    习近平  大家好！“岁月不居，时节如流。”2019年马上就要到了，我在北京向大家致以新年的美好祝福！\...
# 28  29  2020    习近平  2020年就要到了，我在首都北京向大家送上新年的美好祝福！\n2019年，我们用汗水浇灌收获...

# %% [markdown]
# # 형태소 분석

# %%
# jieba(중국어형태소분석기) 중 품사태깅 요소를 pseg 별명으로 실행하기
import jieba
import jieba.posseg as pseg

# %%
# "원본데이터"를 대상으로 "jieba"를 사용해서 형태소 분석하기
저장공간  = [] ## 모든 결과를 저장할 빈 공간으로 "저장공간" 설정
for index, row in 원본데이터.iterrows():# 원본데이터의 컬럼(열)을 불러와서 반복할 준비!
    textdata = row[3]  # 분석에서 사용할 텍스트 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    type = row[1]  # 분석에서 사용할 분류 정보가 있는 열을 지정해준다. 주의! python은 0부터 시작한다!
    형태소 = pseg.cut(textdata)  # jieba의 pos 기능을 활용해서 대상 텍스트를 형태소 분리한다.
    for word in 형태소:  # jieba로 도출된 개별 형태소에 추가 정보를 기입하기 위해서 반복해준다.
      형태소종합 = [word.word,word.flag,type,1]  # 형태소종합에 분류정보와 카운트정보를 추가한다.
      저장공간.append(형태소종합) # 형태소종합의 내용을 종합하여 저장한다.
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.994 seconds.
# Prefix dict has been built successfully.

# %%
# "형태소" 변수의 저장 내용 확인
형태소
# Out:
# <generator object cut at 0x7fd0c88380a0>

# %%
# "형태소종합" 변수의 저장 내용 확인
형태소종합
# Out:
# ['！', 'x', 2020, 1]

# %%
# "저장공간" 변수의 저장 내용 확인
저장공간
# Out:
# [['女士们', 'n', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['先生', 'n', 1992, 1],
#  ['们', 'k', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['们', 'k', 1992, 1],
#  ['：', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['岁序更新', 'i', 1992, 1],
#  ['之际', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我', 'r', 1992, 1],
#  ['通过', 'p', 1992, 1],
#  ['中国国际广播电台', 'nt', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['向', 'p', 1992, 1],
#  ['海外', 's', 1992, 1],
#  ['各位朋友', 'l', 1992, 1],
#  ['致以', 'v', 1992, 1],
#  ['亲切', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['问候', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['衷心祝愿', 'n', 1992, 1],
#  ['大家', 'n', 1992, 1],
#  ['新年快乐', 'l', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['合家幸福', 'i', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['万事如意', 'i', 1992, 1],
#  ['！', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['们', 'k', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['过去', 't', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['1991', 'm', 1992, 1],
#  ['年', 'm', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['对于', 'p', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['来说', 'u', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['不', 'd', 1992, 1],
#  ['平凡', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['一年', 'm', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['国际风云', 'nz', 1992, 1],
#  ['急剧', 'd', 1992, 1],
#  ['变幻', 'v', 1992, 1],
#  ['面前', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['国内', 's', 1992, 1],
#  ['遭受', 'v', 1992, 1],
#  ['严重', 'a', 1992, 1],
#  ['洪涝灾害', 'l', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['情况', 'n', 1992, 1],
#  ['下', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['表现', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['坚定', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['信念', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['民族', 'n', 1992, 1],
#  ['显示', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['极强', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['凝聚力', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['保持', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['政治', 'n', 1992, 1],
#  ['稳定', 'a', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['社会', 'n', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['经济', 'n', 1992, 1],
#  ['建设', 'vn', 1992, 1],
#  ['取得', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['巨大', 'a', 1992, 1],
#  ['成绩', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['国民', 'n', 1992, 1],
#  ['生产总值', 'n', 1992, 1],
#  ['增长率', 'n', 1992, 1],
#  ['达到', 'v', 1992, 1],
#  ['6', 'x', 1992, 1],
#  ['%', 'x', 1992, 1],
#  ['以上', 'f', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['农业', 'n', 1992, 1],
#  ['赢得', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['历史', 'n', 1992, 1],
#  ['上', 'f', 1992, 1],
#  ['第二个', 'm', 1992, 1],
#  ['高产', 'n', 1992, 1],
#  ['年', 'm', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['粮食产量', 'l', 1992, 1],
#  ['达到', 'v', 1992, 1],
#  ['4', 'x', 1992, 1],
#  ['．', 'x', 1992, 1],
#  ['35', 'm', 1992, 1],
#  ['亿吨', 'm', 1992, 1],
#  ['；', 'x', 1992, 1],
#  ['工业生产', 'n', 1992, 1],
#  ['全面', 'n', 1992, 1],
#  ['回升', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['特别', 'd', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['乡镇企业', 'n', 1992, 1],
#  ['突破', 'vn', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['10000', 'm', 1992, 1],
#  ['亿元', 'm', 1992, 1],
#  ['产值', 'n', 1992, 1],
#  ['大关', 'ns', 1992, 1],
#  ['；', 'x', 1992, 1],
#  ['国内', 's', 1992, 1],
#  ['市场供应', 'n', 1992, 1],
#  ['充足', 'a', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['销售', 'vn', 1992, 1],
#  ['旺盛', 'a', 1992, 1],
#  ['；', 'x', 1992, 1],
#  ['物价', 'n', 1992, 1],
#  ['平稳', 'a', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['外商', 'n', 1992, 1],
#  ['来华', 'v', 1992, 1],
#  ['投资', 'vn', 1992, 1],
#  ['企业', 'n', 1992, 1],
#  ['超过', 'v', 1992, 1],
#  ['10000', 'm', 1992, 1],
#  ['家', 'm', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['协议', 'n', 1992, 1],
#  ['外资', 'n', 1992, 1],
#  ['金额', 'n', 1992, 1],
#  ['超过', 'v', 1992, 1],
#  ['100', 'm', 1992, 1],
#  ['亿美元', 'm', 1992, 1],
#  ['；', 'x', 1992, 1],
#  ['对外贸易', 'l', 1992, 1],
#  ['有', 'v', 1992, 1],
#  ['较大', 'a', 1992, 1],
#  ['增长', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['外汇储备', 'n', 1992, 1],
#  ['增加', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['11', 'm', 1992, 1],
#  ['亿', 'm', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['安居乐业', 'nz', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['各项事业', 'l', 1992, 1],
#  ['欣欣向荣', 'i', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['过去', 't', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['一年', 'm', 1992, 1],
#  ['里', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['同', 'p', 1992, 1],
#  ['周边国家', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['睦邻友好', 'l', 1992, 1],
#  ['关系', 'n', 1992, 1],
#  ['更加', 'd', 1992, 1],
#  ['巩固', 'v', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['同', 'p', 1992, 1],
#  ['其他', 'r', 1992, 1],
#  ['地区', 'n', 1992, 1],
#  ['发展中国家', 'l', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['友好合作', 'a', 1992, 1],
#  ['关系', 'n', 1992, 1],
#  ['进一步', 'd', 1992, 1],
#  ['加强', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['同', 'p', 1992, 1],
#  ['西方', 's', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['关系', 'n', 1992, 1],
#  ['也', 'd', 1992, 1],
#  ['有', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['明显', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['改善', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['世界', 'n', 1992, 1],
#  ['事务', 'n', 1992, 1],
#  ['中', 'f', 1992, 1],
#  ['发挥', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['重要', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['作用', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['国际', 'n', 1992, 1],
#  ['地位', 'n', 1992, 1],
#  ['日益', 'n', 1992, 1],
#  ['提高', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['遍', 'v', 1992, 1],
#  ['天下', 's', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['所以', 'c', 1992, 1],
#  ['能够', 'v', 1992, 1],
#  ['取得', 'v', 1992, 1],
#  ['这些', 'r', 1992, 1],
#  ['成就', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['关键在于', 'n', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['坚定不移', 'i', 1992, 1],
#  ['地', 'uv', 1992, 1],
#  ['执行', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['改革开放', 'nz', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['政策', 'n', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['许多', 'm', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['曾一度', 'd', 1992, 1],
#  ['担心', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['改革开放', 'nz', 1992, 1],
#  ['能否', 'v', 1992, 1],
#  ['继续下去', 'i', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我', 'r', 1992, 1],
#  ['可以', 'c', 1992, 1],
#  ['告诉', 'v', 1992, 1],
#  ['大家', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['改革开放', 'nz', 1992, 1],
#  ['使', 'v', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['获得', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['巨大', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['进步', 'd', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['没有', 'v', 1992, 1],
#  ['任何', 'r', 1992, 1],
#  ['道理', 'n', 1992, 1],
#  ['停止', 'v', 1992, 1],
#  ['改革开放', 'nz', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['而', 'c', 1992, 1],
#  ['只', 'd', 1992, 1],
#  ['会', 'v', 1992, 1],
#  ['加快', 'v', 1992, 1],
#  ['其', 'r', 1992, 1],
#  ['步伐', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['只', 'd', 1992, 1],
#  ['会', 'v', 1992, 1],
#  ['搞', 'v', 1992, 1],
#  ['得', 'ud', 1992, 1],
#  ['更好', 'd', 1992, 1],
#  ['更', 'd', 1992, 1],
#  ['扎实', 'a', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['从', 'p', 1992, 1],
#  ['这', 'r', 1992, 1],
#  ['一', 'm', 1992, 1],
#  ['伟大', 'a', 1992, 1],
#  ['实践', 'v', 1992, 1],
#  ['中', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['看到', 'v', 1992, 1],
#  ['了', 'ul', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['民族', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['光明前途', 'i', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['正', 'd', 1992, 1],
#  ['满怀信心', 'i', 1992, 1],
#  ['地', 'uv', 1992, 1],
#  ['去', 'v', 1992, 1],
#  ['创造', 'v', 1992, 1],
#  ['自己', 'r', 1992, 1],
#  ['美好', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['生活', 'vn', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['改革开放', 'nz', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['保持', 'v', 1992, 1],
#  ['社会', 'n', 1992, 1],
#  ['稳定', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['前提', 'n', 1992, 1],
#  ['下', 'f', 1992, 1],
#  ['进行', 'v', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['历史', 'n', 1992, 1],
#  ['上', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['没有', 'v', 1992, 1],
#  ['任何', 'r', 1992, 1],
#  ['一个', 'm', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['动乱', 'n', 1992, 1],
#  ['不已', 'd', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['情况', 'n', 1992, 1],
#  ['下', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['搞', 'v', 1992, 1],
#  ['成', 'n', 1992, 1],
#  ['改革', 'vn', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['要', 'v', 1992, 1],
#  ['积极', 'ad', 1992, 1],
#  ['地', 'uv', 1992, 1],
#  ['推进', 'v', 1992, 1],
#  ['经济体制', 'n', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['政治', 'n', 1992, 1],
#  ['体制改革', 'l', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['建设', 'vn', 1992, 1],
#  ['好', 'a', 1992, 1],
#  ['有', 'v', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['特色', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['社会主义', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['从根本上', 'd', 1992, 1],
#  ['确保', 'v', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['长治久安', 'l', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['稳定', 'a', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['对', 'p', 1992, 1],
#  ['亚太地区', 'ns', 1992, 1],
#  ['乃至', 'c', 1992, 1],
#  ['整个', 'b', 1992, 1],
#  ['世界', 'n', 1992, 1],
#  ['都', 'd', 1992, 1],
#  ['具有', 'v', 1992, 1],
#  ['重要', 'a', 1992, 1],
#  ['意义', 'n', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['这', 'r', 1992, 1],
#  ['一点', 'm', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['已经', 'd', 1992, 1],
#  ['被', 'p', 1992, 1],
#  ['越来越', 'd', 1992, 1],
#  ['多', 'm', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['人', 'n', 1992, 1],
#  ['所', 'u', 1992, 1],
#  ['认识', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['们', 'k', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['实现', 'v', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['现代化', 'vn', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['过程', 'n', 1992, 1],
#  ['中', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['一直', 'd', 1992, 1],
#  ['得到', 'v', 1992, 1],
#  ['世界', 'n', 1992, 1],
#  ['各国', 'r', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['理解', 'v', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['支持', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我', 'r', 1992, 1],
#  ['愿', 'v', 1992, 1],
#  ['倍', 'q', 1992, 1],
#  ['此', 'r', 1992, 1],
#  ['机会', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['向', 'p', 1992, 1],
#  ['所有', 'b', 1992, 1],
#  ['支持', 'v', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['帮助', 'v', 1992, 1],
#  ['过', 'ug', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['各国', 'r', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['当然', 'd', 1992, 1],
#  ['也', 'd', 1992, 1],
#  ['包括', 'v', 1992, 1],
#  ['各位', 'r', 1992, 1],
#  ['热心', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['听众', 'n', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['表示', 'v', 1992, 1],
#  ['诚挚', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['谢意', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我', 'r', 1992, 1],
#  ['还要', 'c', 1992, 1],
#  ['特别', 'd', 1992, 1],
#  ['向', 'p', 1992, 1],
#  ['那些', 'r', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['遭受', 'v', 1992, 1],
#  ['洪涝灾害', 'l', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['时候', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['伸出', 'v', 1992, 1],
#  ['援助', 'vn', 1992, 1],
#  ['之', 'u', 1992, 1],
#  ['手', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['港澳台', 'm', 1992, 1],
#  ['同胞', 'n', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['海外侨胞', 'n', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['国际友人', 'nz', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['表示', 'v', 1992, 1],
#  ['由衷', 'd', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['感谢', 'v', 1992, 1],
#  ['！', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['各位朋友', 'l', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['新', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['一年', 'm', 1992, 1],
#  ['里', 'f', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我国', 'r', 1992, 1],
#  ['各族人民', 'l', 1992, 1],
#  ['将', 'd', 1992, 1],
#  ['更加', 'd', 1992, 1],
#  ['紧密', 'a', 1992, 1],
#  ['地', 'uv', 1992, 1],
#  ['团结起来', 'l', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['一心', 'd', 1992, 1],
#  ['—', 'x', 1992, 1],
#  ['意地', 'n', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['经济', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['保持', 'v', 1992, 1],
#  ['国民经济', 'n', 1992, 1],
#  ['稳步增长', 'i', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['促进', 'v', 1992, 1],
#  ['社会', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['全面进步', 'n', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['投资', 'vn', 1992, 1],
#  ['环境', 'n', 1992, 1],
#  ['将', 'd', 1992, 1],
#  ['进一步', 'd', 1992, 1],
#  ['改善', 'v', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['大门', 'n', 1992, 1],
#  ['永远', 'd', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['敞开', 'v', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['欢迎', 'v', 1992, 1],
#  ['各国', 'r', 1992, 1],
#  ['工商界', 'n', 1992, 1],
#  ['朋友', 'n', 1992, 1],
#  ['来华', 'v', 1992, 1],
#  ['投资', 'vn', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['将', 'd', 1992, 1],
#  ['继续', 'v', 1992, 1],
#  ['奉行', 'v', 1992, 1],
#  ['独立自主', 'i', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['和平', 'nz', 1992, 1],
#  ['外交政策', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['坚持', 'v', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['和平共处', 'nz', 1992, 1],
#  ['五项原则', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['基础', 'n', 1992, 1],
#  ['上同', 'ns', 1992, 1],
#  ['世界', 'n', 1992, 1],
#  ['各国', 'r', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['友好合作', 'a', 1992, 1],
#  ['关系', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['积极参与', 'i', 1992, 1],
#  ['国际', 'n', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['地区', 'n', 1992, 1],
#  ['事务', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['促进', 'v', 1992, 1],
#  ['世界', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['和平', 'nz', 1992, 1],
#  ['与', 'p', 1992, 1],
#  ['发展', 'vn', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['为', 'p', 1992, 1],
#  ['建立', 'v', 1992, 1],
#  ['一个', 'm', 1992, 1],
#  ['公正', 'nr', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['合理', 'vn', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['国际', 'n', 1992, 1],
#  ['新', 'a', 1992, 1],
#  ['秩序', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['作出', 'v', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['应有', 'v', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['贡献', 'n', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['欣逢佳节', 'i', 1992, 1],
#  ['来临', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['格外', 'd', 1992, 1],
#  ['思念', 'n', 1992, 1],
#  ['台湾', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['骨肉同胞', 'l', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['海峡两岸', 'n', 1992, 1],
#  ['人民', 'n', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['分离', 'v', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['不会', 'v', 1992, 1],
#  ['长久', 'd', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['迟早', 'd', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['要', 'v', 1992, 1],
#  ['走到', 'v', 1992, 1],
#  ['一', 'm', 1992, 1],
#  ['起来', 'v', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['两岸', 'f', 1992, 1],
#  ['应该', 'v', 1992, 1],
#  ['在', 'p', 1992, 1],
#  ['人员', 'n', 1992, 1],
#  ['往来', 't', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['经济', 'n', 1992, 1],
#  ['贸易', 'vn', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['科技', 'n', 1992, 1],
#  ['文化交流', 'n', 1992, 1],
#  ['等', 'u', 1992, 1],
#  ['方面', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['不断', 'd', 1992, 1],
#  ['有', 'v', 1992, 1],
#  ['新', 'a', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['进展', 'vn', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['加强', 'v', 1992, 1],
#  ['相互', 'd', 1992, 1],
#  ['联系', 'n', 1992, 1],
#  ['和', 'c', 1992, 1],
#  ['了解', 'v', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['早日', 't', 1992, 1],
#  ['完成', 'v', 1992, 1],
#  ['祖国', 'n', 1992, 1],
#  ['和平', 'nz', 1992, 1],
#  ['统一大业', 'l', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['1992', 'm', 1992, 1],
#  ['年', 'm', 1992, 1],
#  ['是', 'v', 1992, 1],
#  ['“', 'x', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['友好', 'a', 1992, 1],
#  ['观光', 'n', 1992, 1],
#  ['年', 'm', 1992, 1],
#  ['”', 'x', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['我', 'r', 1992, 1],
#  ['热诚', 'a', 1992, 1],
#  ['希望', 'v', 1992, 1],
#  ['各位朋友', 'l', 1992, 1],
#  ['能', 'v', 1992, 1],
#  ['前来', 't', 1992, 1],
#  ['中国', 'ns', 1992, 1],
#  ['旅游', 'vn', 1992, 1],
#  ['、', 'x', 1992, 1],
#  ['参观', 'n', 1992, 1],
#  ['，', 'x', 1992, 1],
#  ['亲眼', 'd', 1992, 1],
#  ['看一看', 'v', 1992, 1],
#  ['我们', 'r', 1992, 1],
#  ['美丽', 'ns', 1992, 1],
#  ['的', 'uj', 1992, 1],
#  ['国家', 'n', 1992, 1],
#  ['。', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['再', 'd', 1992, 1],
#  ['一次', 'm', 1992, 1],
#  ['祝', 'v', 1992, 1],
#  ['各位朋友', 'l', 1992, 1],
#  ['新年好', 'l', 1992, 1],
#  ['！', 'x', 1992, 1],
#  ['\n', 'x', 1992, 1],
#  ['谢谢', 'nr', 1992, 1],
#  ['！', 'x', 1992, 1],
#  ['各位', 'r', 1993, 1],
#  ['听众', 'n', 1993, 1],
#  ['朋友', 'n', 1993, 1],
#  ['：', 'x', 1993, 1],
#  ['\n', 'x', 1993, 1],
#  ['1993', 'm', 1993, 1],
#  ['年', 'm', 1993, 1],
#  ['来到', 'v', 1993, 1],
#  ['了', 'ul', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['我', 'r', 1993, 1],
#  ['很', 'd', 1993, 1],
#  ['高兴', 'b', 1993, 1],
#  ['再次', 'd', 1993, 1],
#  ['通过', 'p', 1993, 1],
#  ['中国国际广播电台', 'nt', 1993, 1],
#  ['向', 'p', 1993, 1],
#  ['各国', 'r', 1993, 1],
#  ['朋友', 'n', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['台湾同胞', 'n', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['港澳同胞', 'ns', 1993, 1],
#  ['和', 'c', 1993, 1],
#  ['海外', 's', 1993, 1],
#  ['华侨', 'n', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['华人', 'n', 1993, 1],
#  ['朋友', 'n', 1993, 1],
#  ['拜年', 'v', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['我', 'r', 1993, 1],
#  ['衷心', 'n', 1993, 1],
#  ['地', 'uv', 1993, 1],
#  ['祝愿', 'v', 1993, 1],
#  ['各位', 'r', 1993, 1],
#  ['事业成功', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['生活', 'vn', 1993, 1],
#  ['幸福', 'a', 1993, 1],
#  ['；', 'x', 1993, 1],
#  ['同时', 'c', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['向', 'p', 1993, 1],
#  ['那些', 'r', 1993, 1],
#  ['因', 'p', 1993, 1],
#  ['天灾', 'n', 1993, 1],
#  ['战乱', 'n', 1993, 1],
#  ['而', 'c', 1993, 1],
#  ['蒙受', 'v', 1993, 1],
#  ['痛苦', 'an', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['朋友', 'n', 1993, 1],
#  ['们', 'k', 1993, 1],
#  ['表示慰问', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['祝福', 'nr', 1993, 1],
#  ['他们', 'r', 1993, 1],
#  ['在', 'p', 1993, 1],
#  ['新', 'a', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['一年', 'm', 1993, 1],
#  ['里', 'f', 1993, 1],
#  ['安居乐业', 'nz', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['和', 'c', 1993, 1],
#  ['平安', 'a', 1993, 1],
#  ['样', 'n', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['\n', 'x', 1993, 1],
#  ['刚刚', 'd', 1993, 1],
#  ['过去', 't', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['1992', 'm', 1993, 1],
#  ['年', 'm', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['对', 'p', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['人民', 'n', 1993, 1],
#  ['来说', 'u', 1993, 1],
#  ['是', 'v', 1993, 1],
#  ['一个', 'm', 1993, 1],
#  ['生机勃勃', 'i', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['年份', 'n', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['年初', 't', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['改革开放', 'nz', 1993, 1],
#  ['和', 'c', 1993, 1],
#  ['现代化', 'vn', 1993, 1],
#  ['建设', 'vn', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['总', 'n', 1993, 1],
#  ['设计师', 'n', 1993, 1],
#  ['邓小平', 'nr', 1993, 1],
#  ['同志', 'n', 1993, 1],
#  ['视察', 'v', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['南方', 'f', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['就', 'd', 1993, 1],
#  ['深入', 'v', 1993, 1],
#  ['改革', 'vn', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['扩大开放', 'l', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['加快', 'v', 1993, 1],
#  ['经济', 'n', 1993, 1],
#  ['发展', 'vn', 1993, 1],
#  ['发表', 'v', 1993, 1],
#  ['了', 'ul', 1993, 1],
#  ['重要', 'a', 1993, 1],
#  ['谈话', 'vn', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['在', 'p', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['大', 'a', 1993, 1],
#  ['地上', 's', 1993, 1],
#  ['兴起', 'v', 1993, 1],
#  ['了', 'ul', 1993, 1],
#  ['改革开放', 'nz', 1993, 1],
#  ['和', 'c', 1993, 1],
#  ['现代化', 'vn', 1993, 1],
#  ['建设', 'vn', 1993, 1],
#  ['新', 'a', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['热潮', 'n', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['10', 'm', 1993, 1],
#  ['月', 'm', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['中国共产党', 'nt', 1993, 1],
#  ['召开', 'v', 1993, 1],
#  ['了', 'ul', 1993, 1],
#  ['具有', 'v', 1993, 1],
#  ['历史', 'n', 1993, 1],
#  ['意义', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['第十四次', 'm', 1993, 1],
#  ['全国代表大会', 'nt', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['会议', 'n', 1993, 1],
#  ['系统地', 'n', 1993, 1],
#  ['总结', 'n', 1993, 1],
#  ['了', 'ul', 1993, 1],
#  ['邓小平', 'nr', 1993, 1],
#  ['同志', 'n', 1993, 1],
#  ['关于', 'p', 1993, 1],
#  ['建设', 'vn', 1993, 1],
#  ['有', 'v', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['特色', 'n', 1993, 1],
#  ['社会主义', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['理论', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['确定', 'v', 1993, 1],
#  ['建立', 'v', 1993, 1],
#  ['社会主义', 'n', 1993, 1],
#  ['市场', 'n', 1993, 1],
#  ['经济体制', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['选举', 'v', 1993, 1],
#  ['产生', 'n', 1993, 1],
#  ['了以', 'v', 1993, 1],
#  ['江泽民', 'nr', 1993, 1],
#  ['同志', 'n', 1993, 1],
#  ['为', 'p', 1993, 1],
#  ['核心', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['新', 'a', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['领导集体', 'n', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['一年', 'm', 1993, 1],
#  ['来', 'v', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['社会安定', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['经济', 'n', 1993, 1],
#  ['持续', 'vd', 1993, 1],
#  ['发展', 'vn', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['外交', 'n', 1993, 1],
#  ['更加', 'd', 1993, 1],
#  ['活跃', 'vn', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['人民', 'n', 1993, 1],
#  ['生活', 'vn', 1993, 1],
#  ['水平', 'n', 1993, 1],
#  ['日益', 'n', 1993, 1],
#  ['提高', 'v', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['解放思想', 'i', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['实事求是', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['大胆', 'n', 1993, 1],
#  ['探索', 'v', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['加快', 'v', 1993, 1],
#  ['改革开放', 'nz', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['集中力量', 'n', 1993, 1],
#  ['把', 'p', 1993, 1],
#  ['经济', 'n', 1993, 1],
#  ['建设', 'vn', 1993, 1],
#  ['搞上去', 'v', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['已', 'd', 1993, 1],
#  ['成为', 'v', 1993, 1],
#  ['11', 'm', 1993, 1],
#  ['亿', 'm', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['人', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['共识', 'n', 1993, 1],
#  ['和', 'c', 1993, 1],
#  ['行动', 'vn', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['为此', 'r', 1993, 1],
#  ['我', 'r', 1993, 1],
#  ['感到', 'v', 1993, 1],
#  ['兴奋', 'v', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['我', 'r', 1993, 1],
#  ['坚信', 'v', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['一个', 'm', 1993, 1],
#  ['朝气蓬勃', 'i', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['繁荣昌盛', 'l', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['中国', 'ns', 1993, 1],
#  ['必将', 'd', 1993, 1],
#  ['矗立', 'v', 1993, 1],
#  ['在', 'p', 1993, 1],
#  ['世界', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['东方', 's', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['\n', 'x', 1993, 1],
#  ['各位朋友', 'l', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['一个', 'm', 1993, 1],
#  ['国家', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['经济', 'n', 1993, 1],
#  ['发展', 'vn', 1993, 1],
#  ['离不开', 'v', 1993, 1],
#  ['安定团结', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['政治局面', 'n', 1993, 1],
#  ['，', 'x', 1993, 1],
#  ['世界', 'n', 1993, 1],
#  ['上', 'f', 1993, 1],
#  ['没有', 'v', 1993, 1],
#  ['哪', 'r', 1993, 1],
#  ['一个', 'm', 1993, 1],
#  ['国家', 'n', 1993, 1],
#  ['是', 'v', 1993, 1],
#  ['在', 'p', 1993, 1],
#  ['混乱', 'a', 1993, 1],
#  ['动荡', 'v', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['政治', 'n', 1993, 1],
#  ['环境', 'n', 1993, 1],
#  ['中', 'f', 1993, 1],
#  ['完成', 'v', 1993, 1],
#  ['工业化', 'vn', 1993, 1],
#  ['、', 'x', 1993, 1],
#  ['现代化', 'vn', 1993, 1],
#  ['进程', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ['。', 'x', 1993, 1],
#  ['这个', 'r', 1993, 1],
#  ['历史', 'n', 1993, 1],
#  ['的', 'uj', 1993, 1],
#  ...]

# %%
# 단일 데이터프레임 구조로 변환
분석통합 = pd.DataFrame(저장공간)

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#           0  1     2  3
# 0       女士们  n  1992  1
# 1         、  x  1992  1
# 2        先生  n  1992  1
# 3         们  k  1992  1
# 4         、  x  1992  1
# ...     ... ..   ... ..
# 22524    \n  x  2020  1
# 22525     祝  v  2020  1
# 22526    大家  n  2020  1
# 22527  新年快乐  l  2020  1
# 22528     ！  x  2020  1
#
# [22529 rows x 4 columns]

# %%
# "분석통합" 변수의 컬럼(열) 이름 변경
분석통합.columns = ["형태소", "품사", "분류", "카운트"]

# %%
# "분석통합" 변수의 저장 내용 확인
분석통합
# Out:
#         형태소 품사    분류  카운트
# 0       女士们  n  1992    1
# 1         、  x  1992    1
# 2        先生  n  1992    1
# 3         们  k  1992    1
# 4         、  x  1992    1
# ...     ... ..   ...  ...
# 22524    \n  x  2020    1
# 22525     祝  v  2020    1
# 22526    大家  n  2020    1
# 22527  新年快乐  l  2020    1
# 22528     ！  x  2020    1
#
# [22529 rows x 4 columns]

# %%
# "분석통합" 변수의 내용을 형태소, 품사, 분류가 같은 것을 합치고, 카운트의 총합을 구해서 "그룹통합" 변수에 저장한다.
그룹통합 = 분석통합.groupby(['형태소', '품사', "분류"])['카운트'].sum()

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
# 형태소  품사  분류
# \n   x   1992    12
#          1993     7
#          1994     7
#          1995    10
#          1996     8
#                  ..
# ；    x   1992     4
#          1993     2
#          1995     2
#          1996     2
#          1998     4
# Name: 카운트, Length: 10753, dtype: int64

# %%
# "그룹통합" 변수의 내용을 데이터프레임 형식으로 변환해서 "그룹통합" 변수에 저장한다.
그룹통합 = pd.DataFrame(그룹통합)

# %%
# "그룹통합" 변수의 저장 내용 확인
그룹통합
# Out:
#              카운트
# 형태소 품사 분류
# \n  x  1992   12
#        1993    7
#        1994    7
#        1995   10
#        1996    8
# ...          ...
# ；   x  1992    4
#        1993    2
#        1995    2
#        1996    2
#        1998    4
#
# [10753 rows x 1 columns]

# %%
# "그룹통합" 변수의 내용을 "형태소분석결과.csv" 파일로 저장한다.
# header는 컬럼(열) 정보의 포함 여부이다.
# encoding은 문자코드를 선택하는 것이다. python에서는 기본적으로 utf-8(유니코드)를 사용한다.

그룹통합.to_csv('형태소분석결과.csv', header='true', encoding='utf-8')
